# %% [markdown]
# <a href="https://colab.research.google.com/github/flyingrockingit/NEW_FILES_PROJECTS_-Module-9-onwards-/blob/main/Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ***Capstone Project: Penguin Classfication with Python***

# %% [markdown]
# **Step 1: Importing the File**
#
# This is where you load the dataset from the File Explorer to Google Colab

# %%
from google.colab import files
files = files.upload ()
# Out:
#      <input type="file" id="files-88c36625-c48c-4926-9d8e-3862ddbe2e06" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88c36625-c48c-4926-9d8e-3862ddbe2e06">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Step 2: Inserting the neccessary Python Libraries**
# This is part to import the 4 important libraries in the progamming language "Python" for Data Visualization.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# **Step 3: Reading the file and displaying 21 fields of the data set**
# In this step, you'll read the first 21 data inside the file.

# %%
df = pd.read_csv("penguins_size.csv")
df.head(21)
# Out:
#    species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen              39.1             18.7              181.0
# 1   Adelie  Torgersen              39.5             17.4              186.0
# 2   Adelie  Torgersen              40.3             18.0              195.0
# 3   Adelie  Torgersen               NaN              NaN                NaN
# 4   Adelie  Torgersen              36.7             19.3              193.0
# 5   Adelie  Torgersen              39.3             20.6              190.0
# 6   Adelie  Torgersen              38.9             17.8              181.0
# 7   Adelie  Torgersen              39.2             19.6              195.0
# 8   Adelie  Torgersen              34.1             18.1              193.0
# 9   Adelie  Torgersen              42.0             20.2              190.0
# 10  Adelie  Torgersen              37.8             17.1              186.0
# ...

# %% [markdown]
# **Step 4: Removal of the null values found in the data**

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# **Step 5: Statistics Summary**

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# **Step 6: Drawing a Count Plot**
#
# This is done by using Seaborn libary

# %%
custom_palette = ["#FF5733", "#33FF57", "#3357FF"]
sns.countplot(data=df, x="species", hue="island", palette=custom_palette)
plt.show()

# %% [markdown]
# **Step 7: Compare Feautures by Box-Whisker Plot**

# %%
df.plot(
    kind='box',
    subplots=True,
    layout=(3, 2),
    sharex=False,
    sharey=False,
    figsize=(15, 20))
plt.show()

# %% [markdown]
# **Step 8: Sketching a Histogram**

# %%
df.hist(figsize=(12, 8), color='skyblue')
plt.show()

# %% [markdown]
# **Step 8:Sketching a HeatMap**

# %%
numerical_df = df.select_dtypes(include=['number'])
sns.heatmap(numerical_df.corr(),cmap= "cividis", annot = True)
# Out:
# <Axes: >

# %%
custom_palette = ["#8E44AD", "#3498DB", "#E74C3C"]
sns.countplot(data=df, x="sex", hue="species", palette=custom_palette)
plt.show()

# %%
custom_palette = ["#FF69B4", "#FFB6C1", "#3498DB"]
sns.countplot(data=df, x="sex", hue="island", palette=custom_palette)
plt.show()

# %% [markdown]
# # **Summary of Data Visualization Module**
# In this project I have attempted doing the following codes:
#
#
# 1. Uploading a data file in the file format "CSV"
# 2. Imports necessary libraries for data handling and visualization: pandas, matplotlib, numpy, and seaborn.
# 3. Loading and Previewing Data
# 4. Reads the CSV file named penguins_size.csv into a DataFrame.
# 5. Displays the first 21 rows of the dataset to get an initial look at the data.
# 6. Data Quality Checks:
#
# i. Checks for missing values in the dataset.
#
# ii. Prints information about the DataFrame structure, such as column types and non-null counts.
#
# iii. Displays statistical summaries for numerical columns
#
# 7. Created a bar plot showing the number of penguins of each species grouped by island, using a custom color palette.
# 8. Plotted boxplots for each numerical column to identify outliers.
# 9. Created a histogram to show the distribution of values across the dataset.
# 10. Selecting only numerical columns and displays a heatmap of their correlations, with color mapping and value annotations.
# 11. Created a count plot showing the distribution of penguin sexes across different species with a new color palette.
# 12. Designed another count plot to visualize the distribution of sexes across islands using a different set of colors.
